# %%
import gymnasium as gym
import ale_py

from stable_baselines3 import PPO
from stable_baselines3.common.atari_wrappers import AtariWrapper

# %%
gym.register_envs(ale_py)

# %%
env = gym.make("ALE/KingKong-v5")

# %%
env = AtariWrapper(env)

# %%
model = PPO(
    "CnnPolicy",
    env,
    verbose=1,
    n_steps=128,
    batch_size=256,
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# C:\Users\ddoris\AppData\Local\anaconda3\Lib\site-packages\stable_baselines3\ppo\ppo.py:155: UserWarning: You have specified a mini-batch size of 256, but because the `RolloutBuffer` is of size `n_steps * n_envs = 128`, after every 0 untruncated mini-batches, there will be a truncated mini-batch of size 128
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=128 and n_envs=1)
#   warnings.warn(

# %%
model.learn(total_timesteps=10_000)
# Out:
# ----------------------------
# | time/              |     |
# |    fps             | 102 |
# |    iterations      | 1   |
# |    time_elapsed    | 1   |
# |    total_timesteps | 128 |
# ----------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 203          |
# |    ep_rew_mean          | 2            |
# | time/                   |              |
# |    fps                  | 54           |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0017350283 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.79        |
# |    explained_variance   | -0.00039     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0131       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00688     |
# |    value_loss           | 0.136        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 162          |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 384          |
# | train/                  |              |
# |    approx_kl            | 0.0011611017 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.79        |
# |    explained_variance   | 0.0139       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00366      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00412     |
# |    value_loss           | 0.0436       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 144          |
# |    ep_rew_mean          | 0.667        |
# | time/                   |              |
# |    fps                  | 44           |
# |    iterations           | 4            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 0.0034059365 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.79        |
# |    explained_variance   | -0.283       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0136      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00793     |
# |    value_loss           | 0.00507      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 139          |
# |    ep_rew_mean          | 0.5          |
# | time/                   |              |
# |    fps                  | 41           |
# |    iterations           | 5            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 640          |
# | train/                  |              |
# |    approx_kl            | 0.0013807504 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | 0.704        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00585     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 0.00345      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 132         |
# |    ep_rew_mean          | 0.4         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 6           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | 0.006564652 |
# |    clip_fraction        | 0.0211      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | -0.165      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0254     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 0.00806     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | 0.286       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 7           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 896         |
# | train/                  |             |
# |    approx_kl            | 0.013518942 |
# |    clip_fraction        | 0.0242      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.368       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0101     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00549    |
# |    value_loss           | 0.00395     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | 0.25        |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 8           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.050245732 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | -0.198      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00728    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00874    |
# |    value_loss           | 0.00393     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | 0.25        |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 9           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 1152        |
# | train/                  |             |
# |    approx_kl            | 0.017675169 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.511       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0223     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 0.00157     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 128         |
# |    ep_rew_mean          | 0.2         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 10          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.013882389 |
# |    clip_fraction        | 0.0477      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | -2.06       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0176     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00727    |
# |    value_loss           | 0.00121     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 128         |
# |    ep_rew_mean          | 0.2         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 11          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 1408        |
# | train/                  |             |
# |    approx_kl            | 0.004857477 |
# |    clip_fraction        | 0.0133      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | -0.185      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0081     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00331    |
# |    value_loss           | 0.00158     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | 0.182       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 12          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.005467407 |
# |    clip_fraction        | 0.0477      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | -0.775      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0133     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00616    |
# |    value_loss           | 0.00084     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 130          |
# |    ep_rew_mean          | 0.167        |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 13           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 1664         |
# | train/                  |              |
# |    approx_kl            | 0.0076947175 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.67        |
# |    explained_variance   | -3.32        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0147      |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00599     |
# |    value_loss           | 0.00097      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 129         |
# |    ep_rew_mean          | 0.154       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 14          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 0.018905703 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0185     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00939    |
# |    value_loss           | 0.000373    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 132          |
# |    ep_rew_mean          | 0.214        |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 15           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 1920         |
# | train/                  |              |
# |    approx_kl            | 0.0064944644 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.72        |
# |    explained_variance   | -1.63        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0227      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00938     |
# |    value_loss           | 0.00023      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 132          |
# |    ep_rew_mean          | 0.214        |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 16           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0046607642 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | 0.1          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00371      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00406     |
# |    value_loss           | 0.0428       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 0.333       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 17          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 2176        |
# | train/                  |             |
# |    approx_kl            | 0.004988823 |
# |    clip_fraction        | 0.00625     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | -0.0175     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00441     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00704    |
# |    value_loss           | 0.0511      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | 0.312       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 18          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 2304        |
# | train/                  |             |
# |    approx_kl            | 0.002289426 |
# |    clip_fraction        | 0.0203      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | -1.3        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00889    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 0.0649      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | 0.294       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 19          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 2432        |
# | train/                  |             |
# |    approx_kl            | 0.019393545 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.0378      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0141     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 0.0171      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | 0.278       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 20          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.009438073 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | -0.408      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0207     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.00881     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 138         |
# |    ep_rew_mean          | 0.263       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 21          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 2688        |
# | train/                  |             |
# |    approx_kl            | 0.010275951 |
# |    clip_fraction        | 0.0102      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.00898     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0154     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00751    |
# |    value_loss           | 0.00453     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 139        |
# |    ep_rew_mean          | 0.3        |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 22         |
# |    time_elapsed         | 70         |
# |    total_timesteps      | 2816       |
# | train/                  |            |
# |    approx_kl            | 0.00834653 |
# |    clip_fraction        | 0.0219     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.76      |
# |    explained_variance   | 0.209      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0166    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00805   |
# |    value_loss           | 0.00225    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 139          |
# |    ep_rew_mean          | 0.3          |
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 23           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 2944         |
# | train/                  |              |
# |    approx_kl            | 0.0071429014 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | -0.0142      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0028       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00867     |
# |    value_loss           | 0.0522       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | 0.333       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 24          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.004855306 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00612     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00541    |
# |    value_loss           | 0.0412      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | 0.364       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 25          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 3200        |
# | train/                  |             |
# |    approx_kl            | 0.002530245 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0153     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00693    |
# |    value_loss           | 0.00185     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | 0.348       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 26          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 3328        |
# | train/                  |             |
# |    approx_kl            | 0.007130293 |
# |    clip_fraction        | 0.00625     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00564    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00893    |
# |    value_loss           | 0.0394      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | 0.375       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 27          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 3456        |
# | train/                  |             |
# |    approx_kl            | 0.017385425 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | -0.407      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0237     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 0.00662     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | 0.375       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 28          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.010524538 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.0171      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00512     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00815    |
# |    value_loss           | 0.0439      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 143          |
# |    ep_rew_mean          | 0.4          |
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 29           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 3712         |
# | train/                  |              |
# |    approx_kl            | 0.0021325387 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00948      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00495     |
# |    value_loss           | 0.048        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 142          |
# |    ep_rew_mean          | 0.37         |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 30           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0030183424 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | -1.08        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0253      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0143      |
# |    value_loss           | 0.00219      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | 0.37        |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 31          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 3968        |
# | train/                  |             |
# |    approx_kl            | 0.007482173 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | -0.444      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0161     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 0.0113      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 144          |
# |    ep_rew_mean          | 0.429        |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 32           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0027038157 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | 0.186        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00221     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00838     |
# |    value_loss           | 0.0418       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 145          |
# |    ep_rew_mean          | 0.448        |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 33           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 4224         |
# | train/                  |              |
# |    approx_kl            | 0.0050384267 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.76        |
# |    explained_variance   | 0.255        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0191      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0147      |
# |    value_loss           | 0.0329       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | 0.433       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 34          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 4352        |
# | train/                  |             |
# |    approx_kl            | 0.009904655 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | -0.0656     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0144     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.0527      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | 0.433       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 35          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 4480        |
# | train/                  |             |
# |    approx_kl            | 0.016187398 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.281       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0337     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 0.00629     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | 0.452       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 36          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.006635095 |
# |    clip_fraction        | 0.00391     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.226       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00575    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00826    |
# |    value_loss           | 0.0342      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | 0.452       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 37          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 4736        |
# | train/                  |             |
# |    approx_kl            | 0.023946349 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | -0.424      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0279     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 0.0273      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 149         |
# |    ep_rew_mean          | 0.5         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 38          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 4864        |
# | train/                  |             |
# |    approx_kl            | 0.014562918 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00472    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 0.0553      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 149         |
# |    ep_rew_mean          | 0.485       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 39          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 4992        |
# | train/                  |             |
# |    approx_kl            | 0.028061338 |
# |    clip_fraction        | 0.0234      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | -13.3       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.041      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0278     |
# |    value_loss           | 0.0121      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 0.471       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 40          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.015799114 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0325     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 0.00609     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 0.457       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 41          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 5248        |
# | train/                  |             |
# |    approx_kl            | 0.006429897 |
# |    clip_fraction        | 0.0258      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | -1.01       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00141    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00339    |
# |    value_loss           | 0.0443      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 0.444       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 42          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 5376        |
# | train/                  |             |
# |    approx_kl            | 0.009007448 |
# |    clip_fraction        | 0.093       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00962    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00971    |
# |    value_loss           | 0.0262      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 147          |
# |    ep_rew_mean          | 0.432        |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 43           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 5504         |
# | train/                  |              |
# |    approx_kl            | 0.0077542253 |
# |    clip_fraction        | 0.212        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | -0.557       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00566     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00831     |
# |    value_loss           | 0.0305       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 147         |
# |    ep_rew_mean          | 0.421       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 44          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | 0.013921048 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | -0.698      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00197    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 0.0259      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | 0.41        |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 45          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 5760        |
# | train/                  |             |
# |    approx_kl            | 0.023970434 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.235       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0293     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 0.00774     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 145       |
# |    ep_rew_mean          | 0.4       |
# | time/                   |           |
# |    fps                  | 38        |
# |    iterations           | 46        |
# |    time_elapsed         | 153       |
# |    total_timesteps      | 5888      |
# | train/                  |           |
# |    approx_kl            | 0.0202717 |
# |    clip_fraction        | 0.245     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.59     |
# |    explained_variance   | -0.00545  |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0182   |
# |    n_updates            | 450       |
# |    policy_gradient_loss | -0.0139   |
# |    value_loss           | 0.00757   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 0.39        |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 47          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 6016        |
# | train/                  |             |
# |    approx_kl            | 0.021130117 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0234     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 0.00266     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | 0.39        |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 48          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.052342422 |
# |    clip_fraction        | 0.0234      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | -4.01       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.044      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0233     |
# |    value_loss           | 0.00139     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 147         |
# |    ep_rew_mean          | 0.429       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 49          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 6272        |
# | train/                  |             |
# |    approx_kl            | 0.012410458 |
# |    clip_fraction        | 0.0133      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.0783      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00964     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00781    |
# |    value_loss           | 0.085       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 0.442       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 50          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.009566908 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.161       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0183     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0211     |
# |    value_loss           | 0.0548      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 0.442       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 51          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 6528        |
# | train/                  |             |
# |    approx_kl            | 0.003691651 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | -0.846      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0164     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00832    |
# |    value_loss           | 0.00606     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 0.477       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 52          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 6656        |
# | train/                  |             |
# |    approx_kl            | 0.012027657 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | -0.1        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00729    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 0.0518      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 0.477       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 53          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 6784        |
# | train/                  |             |
# |    approx_kl            | 0.010655798 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.74       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0241     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 0.0487      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 152          |
# |    ep_rew_mean          | 0.467        |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 54           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 6912         |
# | train/                  |              |
# |    approx_kl            | 0.0034276173 |
# |    clip_fraction        | 0.0992       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | -5.77        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0289      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0139      |
# |    value_loss           | 0.00286      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | 0.457       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 55          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 7040        |
# | train/                  |             |
# |    approx_kl            | 0.015005292 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0464     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0264     |
# ...
# |    value_loss           | 0.00729    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 149        |
# |    ep_rew_mean          | 0.396      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 62         |
# |    time_elapsed         | 203        |
# |    total_timesteps      | 7936       |
# | train/                  |            |
# |    approx_kl            | 0.03613742 |
# |    clip_fraction        | 0.0945     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.67      |
# |    explained_variance   | -6.71      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0402    |
# |    n_updates            | 610        |
# |    policy_gradient_loss | -0.0269    |
# |    value_loss           | 0.00346    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 149         |
# |    ep_rew_mean          | 0.396       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 63          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 8064        |
# | train/                  |             |
# |    approx_kl            | 0.008266561 |
# |    clip_fraction        | 0.0203      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | -1.04       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0321     |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 0.00176     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 149         |
# |    ep_rew_mean          | 0.4         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 64          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.019740505 |
# |    clip_fraction        | 0.0305      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.0407      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0111      |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00314    |
# |    value_loss           | 0.05        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 0.393       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 65          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 8320        |
# | train/                  |             |
# |    approx_kl            | 0.007321096 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | -1.35       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00785    |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.00753    |
# |    value_loss           | 0.00826     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 148          |
# |    ep_rew_mean          | 0.393        |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 66           |
# |    time_elapsed         | 217          |
# |    total_timesteps      | 8448         |
# | train/                  |              |
# |    approx_kl            | 0.0047169114 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.72        |
# |    explained_variance   | 0.332        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0187      |
# |    n_updates            | 650          |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 0.00228      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 150           |
# |    ep_rew_mean          | 0.404         |
# | time/                   |               |
# |    fps                  | 38            |
# |    iterations           | 67            |
# |    time_elapsed         | 219           |
# |    total_timesteps      | 8576          |
# | train/                  |               |
# |    approx_kl            | 0.00082382467 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.78         |
# |    explained_variance   | -4.09         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0165       |
# |    n_updates            | 660           |
# |    policy_gradient_loss | -0.00672      |
# |    value_loss           | 0.00133       |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 149         |
# |    ep_rew_mean          | 0.397       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 68          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 8704        |
# | train/                  |             |
# |    approx_kl            | 0.018458754 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | -0.173      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00683    |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 0.0509      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 149         |
# |    ep_rew_mean          | 0.39        |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 69          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 8832        |
# | train/                  |             |
# |    approx_kl            | 0.015603984 |
# |    clip_fraction        | 0.0961      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.168       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0279     |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 0.00245     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 149        |
# |    ep_rew_mean          | 0.383      |
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 70         |
# |    time_elapsed         | 230        |
# |    total_timesteps      | 8960       |
# | train/                  |            |
# |    approx_kl            | 0.02067519 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.64      |
# |    explained_variance   | -2.65      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0319    |
# |    n_updates            | 690        |
# |    policy_gradient_loss | -0.0182    |
# |    value_loss           | 0.00256    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 0.377       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 71          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 9088        |
# | train/                  |             |
# |    approx_kl            | 0.031722404 |
# |    clip_fraction        | 0.477       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | -1.18       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0473     |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.0318     |
# |    value_loss           | 0.00234     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 0.371       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 72          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.027937971 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | -0.0474     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0309     |
# |    n_updates            | 710         |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 0.00216     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 147         |
# |    ep_rew_mean          | 0.365       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 73          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 9344        |
# | train/                  |             |
# |    approx_kl            | 0.031345773 |
# |    clip_fraction        | 0.0719      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | -0.0722     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0304     |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 0.00176     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 0.375       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 74          |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 9472        |
# | train/                  |             |
# |    approx_kl            | 0.044703726 |
# |    clip_fraction        | 0.0344      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | -5.06       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0387     |
# |    n_updates            | 730         |
# |    policy_gradient_loss | -0.0308     |
# |    value_loss           | 0.00301     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 0.369       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 75          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 9600        |
# | train/                  |             |
# |    approx_kl            | 0.013615723 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00596    |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 0.0479      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 0.369       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 76          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.010956678 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -1.35       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0457     |
# |    n_updates            | 750         |
# |    policy_gradient_loss | -0.0313     |
# |    value_loss           | 0.00317     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 0.364       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 77          |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 9856        |
# | train/                  |             |
# |    approx_kl            | 0.007865033 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | -1.64       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0302     |
# |    n_updates            | 760         |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 0.00165     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 148          |
# |    ep_rew_mean          | 0.358        |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 78           |
# |    time_elapsed         | 257          |
# |    total_timesteps      | 9984         |
# | train/                  |              |
# |    approx_kl            | 0.0037969109 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0.828        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0172      |
# |    n_updates            | 770          |
# |    policy_gradient_loss | -0.00855     |
# |    value_loss           | 0.00189      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 0.353       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 79          |
# |    time_elapsed         | 260         |
# |    total_timesteps      | 10112       |
# | train/                  |             |
# |    approx_kl            | 0.027392337 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.127       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0263     |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 0.00274     |
# -----------------------------------------

# %%
model.save("kingkong_ppo1")

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'KingKongModel2.ipynb', 'KingKongModelBase.ipynb', 'kingkong_dqn.zip', 'kingkong_ppo1', 'kingkong_ppo1.zip']

# %%
env = gym.make("ALE/KingKong-v5", render_mode="human")
env = AtariWrapper(env)

from stable_baselines3 import PPO
model = PPO.load("kingkong_ppo1.zip")

obs, _ = env.reset()

while True:
    action, _ = model.predict(obs)
    obs, _, terminated, truncated, _ = env.step(action)

    if terminated or truncated:
        obs, _ = env.reset()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 11
#       9 while True:
#      10     action, _ = model.predict(obs)
# ---> 11     obs, _, terminated, truncated, _ = env.step(action)
#      13     if terminated or truncated:
#      14         obs, _ = env.reset()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\gymnasium\core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\gymnasium\core.py:595, in RewardWrapper.step(self, action)
#     591 def step(
#     592     self, action: ActType
#     593 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     594     """Modifies the :attr:`env` :meth:`step` reward using :meth:`self.reward`."""
# --> 595     observation, reward, terminated, truncated, info = self.env.step(action)
#     596     return observation, self.reward(reward), terminated, truncated, info
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\gymnasium\core.py:560, in ObservationWrapper.step(self, action)
#     556 def step(
#     557     self, action: ActType
#     558 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     559     """Modifies the :attr:`env` after calling :meth:`step` using :meth:`self.observation` on the returned observations."""
# --> 560     observation, reward, terminated, truncated, info = self.env.step(action)
#     561     return self.observation(observation), reward, terminated, truncated, info
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\gymnasium\core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\stable_baselines3\common\atari_wrappers.py:120, in EpisodicLifeEnv.step(self, action)
#     119 def step(self, action: int) -> AtariStepReturn:
# --> 120     obs, reward, terminated, truncated, info = self.env.step(action)
#     121     self.was_real_done = terminated or truncated
#     122     # check current lives, make loss of life terminal,
#     123     # then update lives to handle bonus lives
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\stable_baselines3\common\atari_wrappers.py:186, in MaxAndSkipEnv.step(self, action)
#     184 terminated = truncated = False
#     185 for i in range(self._skip):
# --> 186     obs, reward, terminated, truncated, info = self.env.step(action)
#     187     done = terminated or truncated
#     188     if i == self._skip - 2:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\gymnasium\core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\gymnasium\core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\ale_py\env.py:305, in AtariEnv.step(self, action)
#     303 reward = 0.0
#     304 for _ in range(frameskip):
# --> 305     reward += self.ale.act(action_idx, strength)
#     307 is_terminal = self.ale.game_over(with_truncation=False)
#     308 is_truncated = self.ale.game_truncated()
#
# KeyboardInterrupt:
