# %% [markdown]
# # Given a 60% chance that the elf falls off of the cliff more than 150 times before the end of the round, what is the probability that the elf will end the round without falling off of the cliff more than 150 times for the first time on the 4th run?
#
# In this simulation, we assume that the probability of falling off of the cliff more than 2000 times is 60%.
# Each trial would be running the simulation until the elf reaches the goal. The observed result is how many times the elf falls off of the cliff, with the random variable being the probability.

# %%
x=4
a=x-1
p=.40
q=1-p
tProb = (q**a)*p
print(tProb)
# Out:
# 0.08639999999999999

# %%
# !pip install ale-py
# !pip install pygame
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...

# %%
# First, make sure the pip install commands are executed properly
# !pip install gymnasium
# !pip install 'gymnasium[atari]'
# !pip install gymnasium[accept-rom-license]

# After installation, you may need to restart the kernel
# Use the following command to restart the kernel programmatically
# Or manually restart the kernel from the Jupyter notebook menu
import os
os.kill(os.getpid(), 9)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
# WARNING: gymnasium 1.2.1 does not provide the extra 'accept-rom-license'
# ...

# %%
import ale_py
import gymnasium as gym

env = gym.make("CliffWalking-v1", render_mode="ansi")  # 'ansi' gives text output
state, info = env.reset()
print("Initial state:", state)
# Out:
# Initial state: 36

# %%
n_trials = 100
n_episodes = 5
count4 = 0  # Number of times success first occurs on 4th episode

for trial in range(n_trials):
    cliffCount = 0
    moveCount = 0
    success_found = False  # To track the first success in this trial

    for episode in range(n_episodes):
        state, info = env.reset()
        total_reward = 0
        done = False
        cliffCount = 0  # Reset for each episode

        while not done:
            action = env.action_space.sample()
            next_state, reward, terminated, truncated, info = env.step(action)

            if reward == -100:
                cliffCount += 1
            else:
                moveCount += 1

            total_reward += reward
            done = terminated or truncated

        print(f"Trial {trial + 1}, Episode {episode + 1}: Reward = {total_reward}, Cliff falls = {cliffCount}")

        # Check if this episode meets the condition (goal reached with <150 cliff falls)
        if cliffCount < 150 and not success_found:
            success_found = True  # first success found this trial
            if episode == 3:  # 4th episode (0-indexed)
                count4 += 1
                print(f"✅ Success first occurred on episode 4 in trial {trial + 1}")

print(f"\nNumber of times success first occurred on episode 4: {count4}")
# Out:
# Trial 1, Episode 1: Reward = -105587, Cliff falls = 961
# Trial 1, Episode 2: Reward = -91547, Cliff falls = 836
# Trial 1, Episode 3: Reward = -934, Cliff falls = 8
# Trial 1, Episode 4: Reward = -232962, Cliff falls = 2134
# Trial 1, Episode 5: Reward = -11698, Cliff falls = 107
# Trial 2, Episode 1: Reward = -16399, Cliff falls = 148
# Trial 2, Episode 2: Reward = -193768, Cliff falls = 1774
# Trial 2, Episode 3: Reward = -223659, Cliff falls = 2019
# Trial 2, Episode 4: Reward = -1802, Cliff falls = 16
# Trial 2, Episode 5: Reward = -59864, Cliff falls = 541
# Trial 3, Episode 1: Reward = -65814, Cliff falls = 604
# Trial 3, Episode 2: Reward = -5443, Cliff falls = 51
# Trial 3, Episode 3: Reward = -54324, Cliff falls = 494
# Trial 3, Episode 4: Reward = -23676, Cliff falls = 214
# Trial 3, Episode 5: Reward = -32589, Cliff falls = 300
# Trial 4, Episode 1: Reward = -2733, Cliff falls = 25
# Trial 4, Episode 2: Reward = -27586, Cliff falls = 249
# ...

# %%
p_empirical = count4 / n_trials
print(f"Empirical probability of first success on episode 4: {p_empirical:.4f}")
# Out:
# Empirical probability of first success on episode 4: 0.0800

# %% [markdown]
# # Answer:
#
# Despite assuming a probability of 60%, the empirical probability of successfully reaching the goal without falling off of the cliff 150 times on the fourth trial, 8%, is close to the theoretical probability, which is 8.63999%.
